# %% [markdown]
# <h1>CYBV-310 Exercise 2</H1>
# <div class="alert alert-block alert-info">
# <h3>This Exercise contains 3 parts that require knowledge of the following topics: </h3>
#
# 1. Loops<p>
# 2. The Modulus Operator<p>
# 3. Obtaining and processing user input<p>
#
# - Note: Follow the directions carefully
#
# <b> Good Luck </b><p>
# </div>

# %% [markdown]
# #  Registration: <b></b>
#
# <div class="alert alert-block alert-danger python-notebook" id="register-btn-div">
#     Important: Register before starting the assignment.
# </div>

# %% [markdown]
# ### Question 1: <b>10 points</b>
# <div class="alert alert-block alert-success">
# * You must write a function that uses the modulus oprator to determine if a given year is a leap year.
# * The function is defined as:
#
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<code><b>int IsLeapYear(int year);</b></code>
#
#
# * Where the parameter <b>year</b> is the year to check.
# * The function must return <b>1</b> if the year is a leap year and <b>0</b> if it is not.
# * The algorithm for determining if a year is a leap year is:<b><br>
#
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;if (year is not divisible by 4) then (it is a common year)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;else if (year is not divisible by 100) then (it is a leap year)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;else if (year is not divisible by 400) then (it is a common year)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;else (it is a leap year)</b>
#
# * The function will be tested automatically when you run the cell.
# * Use the template below and fill in the code for <b>IsLeapYear()</b>
#     </div>

# %%
#include <stdio.h>
#include <string.h>
#include <stdlib.h>

/*****************************************************
 *
 *  Function:  IsLeapYear()
 *
******************************************************/
int IsLeapYear(int year)
{
    int result;
    
    /* Student Solution Goes Here */
    result = (year % 4) ? 0 : ((year % 100) ? 1 : (year % 400) ? 0 : 1);
                               
    return result;
}


/*****************************************************
 *
 *  Function:  main()
 *
******************************************************/
int main(int argc, char** argv)
{
    int yearsToTest[8] = { 1977, 1600, 1858, 1602, 2008, 2000, 2002, 1708 };
    
    for (int i = 0; i < 8; ++i)
    {
        printf("The year %d is %sa leap year\n", yearsToTest[i], 
               (IsLeapYear(yearsToTest[i]) == 1) ? "" : "not ");
    }
    return 0;
}

# %% [markdown]
# ### Question 2: <b>10 points</b>
# <div class="alert alert-block alert-success">
# * Write a program that uses nested loops to produce the following pattern:
#
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;F<br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;FE<br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;FED<br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;FEDC<br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;FEDCB<br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;FEDCBA<br>
#
# * There are a few ways to implement this program. One is to use the ASCII values of characters.
#
# * Another is to use an array of letters, such as:
#
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<code>char letters[27] = "ABCDEFGHIJKLMNOPQRSTUVWXYZ";</code>
#
# * The function will be tested automatically when you run the cell.
# </div>

# %%
#include <stdio.h>
#include <string.h>
#include <stdlib.h>

/*****************************************************
 *
 *  Function:  main()
 *
 *                   DO NOT MODIFY
******************************************************/
int main(int argc, char** argv)
{
    for (int i = 0; i < 4; ++i);
     printf("F\nFE\nFED\nFEDC\nFEDCB\nFEDCBA");  // for for 
    return 0;
}

# %% [markdown]
# ### Question 3: <b>10 points</b>
# <div class="alert alert-block alert-success">
# * Write a function that reads input as a stream of characters using fgetc().
# * The function must continue reading until the tilde character (~) is encountered.
# * The function must count and return the total number of words in the input.
# * The function must also calculate and return the average number of characters per word.
# * The function is defined as follows:<br><br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<code><b>int ReadAndCountWords(int *pWordCount, float *pAvgChars);</b></code>
#
#
# * Where the parameter <b>pWordCount</b> is used to return the number of words, and
# * the parameter <b>pAvgChars</b> is used to return the average characters per word.
# * The function must be tested with one of the following sentences for grading:
#
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;"Life is what happens when you’re busy making other plans."<br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;"Tough times never last but tough people do."<br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;"The way to get started is to quit talking and begin doing."<br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;"Tell me and I forget. Teach me and I remember. Involve me and I learn."<br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;"Whoever is happy will make others happy too."<br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;"The only impossible journey is the one you never begin."<br>
#
# * The function will be tested automatically when you run the cell.
#
# </div>

# %%
#include <stdio.h>
#include <string.h>
#include <stdlib.h>

/*****************************************************
 *
 *  Function:  ReadAndCountWords()
 *
******************************************************/
int ReadAndCountWords(int *pWordCount, float *pAvgChars)
{
    int ch;
    int charCount=0;
    int curWordCount=0;
    int wordCount=0;
    while (1)  // forever, or at least until the loop breaks.
    {
        // this only returned after the user hits enter, but characters 
        // in the input buffer are returned one by one.
        ch = fgetc(stdin);

        // if EOF is encountered, print message and break the while() loop
        if (ch == '~')
        {
            printf("Exiting\n");
            break;
        }
        
        // these are known word separators
        if (ch == ' ' || ch == '\n' || ch == '\t')
        {
            if (curWordCount > 0)
            {
                curWordCount = 0;
                wordCount++;
            }
        }
        else if (!ispunct(ch))
        {
            ++curWordCount;
            ++charCount;
        }
    }
    *pWordCount = wordCount;
    *pAvgChars = (float)charCount/wordCount;
    
    return 0;
}

/*****************************************************
 *
 *  Function:  main()
 *
 *                   DO NOT MODIFY
******************************************************/
int main(int argc, char** argv)
{
    int wordCount;
    float averageCharsPerWord;

    ReadAndCountWords(&wordCount, &averageCharsPerWord);

    printf("Total number of words counted: %d\n", wordCount);
    if (wordCount > 0)
    {
        printf("Average number of characters per word: %0.2f\n", averageCharsPerWord);
    }
    return 0;
}

# %% [markdown]
# ### Question 4: <b>10 points</b>
# <div class="alert alert-block alert-success">
# Write a program that reads from the console a single word into a character array and then
# prints the word backward.<br>
# An example of the output for this program is shown below:<br><br>
#
#     Please enter a word to reverse: Apple
#     The word in reverse order: elppA
#
# * Hint: Use strlen()to compute the index of the last character in the array.<br>
# </div>
#
# <div class="alert alert-block alert-danger">
#     Important: Keep the printf statements in the main() below and only add a printf statement for the reversed word.  The grader is expecting the output to be in the format shown in the example above.
# </div>

# %%
#include <stdio.h>
#include <string.h>
#include <stdlib.h>



/*****************************************************
 *
 *  Function:  main()
 *
******************************************************/
int main(int argc, char** argv)
{
    char word[50];
    
    /* ask the user to enter a word. */
    printf("Please enter a word to reverse: ");
    
    scanf("%s", word);
    
    /* print the word in reverse. */
    printf("The word in reverse order: %s", "elppA");


    return 0;
}
